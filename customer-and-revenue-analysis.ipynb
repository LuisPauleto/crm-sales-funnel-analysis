# %% [markdown]
# <a href="https://colab.research.google.com/github/LuisPauleto/crm-sales-funnel-analysis/blob/main/customer-and-revenue-analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #### Pacotes Utilizados

# %%
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### Extração

# %%
df_receitas = pd.read_excel("/content/drive/MyDrive/Relatorio_de_receitas_e_matricula.xlsx")

# %%
len(df_receitas)
# Out:
# 1311

# %%
df_receitas.head(10)
# Out:
#    Unnamed: 0       Data       Descrição   Valor     Tipo  mensalidade  \
# 0          37 2023-02-01  #CLIENTE#23001  367.73  Crédito       367.73
# 1         115 2023-03-01  #CLIENTE#23001  367.73  Crédito         0.00
# 2         194 2023-04-01  #CLIENTE#23001  367.73  Crédito         0.00
# 3         279 2023-05-01  #CLIENTE#23001  367.73  Crédito         0.00
# 4         358 2023-06-01  #CLIENTE#23001  367.73  Crédito         0.00
# 5         438 2023-07-01  #CLIENTE#23001  367.73  Crédito         0.00
# 6         516 2023-08-01  #CLIENTE#23001  367.73  Crédito         0.00
# 7         603 2023-09-01  #CLIENTE#23001  367.73  Crédito         0.00
# 8         698 2023-10-01  #CLIENTE#23001  367.73  Crédito         0.00
# 9         789 2023-11-01  #CLIENTE#23001  367.73  Crédito         0.00
#
#    receita
# 0     0.00
# 1   367.73
# 2   367.73
# 3   367.73
# 4   367.73
# 5   367.73
# 6   367.73
# 7   367.73
# 8   367.73
# 9   367.73

# %% [markdown]
# #### Data Cleaning

# %%
# Dropar a coluna Unnamed
df_receitas.drop(columns = ['Unnamed: 0'], inplace=True)

# %%
# Filtrar apenas os clientes (formato #CLIENTE...)
df_receitas['is_client'] = df_receitas['Descrição'].str.contains('#CLIENTE#\d*', regex=True)

# %%
len(df_receitas[df_receitas['is_client']==False])
# Out:
# 13

# %%
df_receitas[df_receitas['is_client']==False].head(13)
# Out:
#            Data                       Descrição     Valor            Tipo  \
# 1298 2023-12-01                 Aluguel de sala    750.00        Dinheiro
# 1299 2024-01-21                 Aluguel de sala    750.00        Dinheiro
# 1300 2023-01-19                        Depósito    375.26  Aporte pessoal
# 1301 2023-06-14                        Depósito    146.87  Aporte pessoal
# 1302 2023-07-19           Espetáculo de Inverno   6948.14      Espetáculo
# 1303 2023-12-26        Espetáculo de fim de ano  21213.05      Espetáculo
# 1304 2023-02-28  Rendimentos conta Mercado Pago     44.18    Investimento
# 1305 2023-03-31  Rendimentos conta Mercado Pago     37.44    Investimento
# 1306 2023-02-28               Venda de Uniforme    734.63        Dinheiro
# 1307 2023-03-01               Venda de Uniforme    140.00        Dinheiro
# 1308 2023-04-30               Venda de Uniforme     75.20        Dinheiro
# 1309 2023-07-03               Venda de Uniforme    767.27        Dinheiro
# 1310 2023-09-20               Venda de Uniforme    181.52        Dinheiro
#
#       mensalidade  receita  is_client
# 1298       750.00     0.00      False
# 1299         0.00   750.00      False
# 1300       375.26     0.00      False
# 1301         0.00   146.87      False
# 1302      6948.14     0.00      False
# 1303     21213.05     0.00      False
# 1304        44.18     0.00      False
# 1305         0.00    37.44      False
# 1306       734.63     0.00      False
# 1307         0.00   140.00      False
# 1308         0.00    75.20      False
# 1309         0.00   767.27      False
# 1310         0.00   181.52      False

# %%
# Excluir essas linhas
df_receitas = df_receitas.loc[df_receitas["is_client"] == True]

# %%
len(df_receitas)
# Out:
# 1298

# %%
df_receitas.drop(columns = 'is_client', inplace=True)

# %% [markdown]
# Agora temos apenas clientes no campo "Descrição"

# %% [markdown]
# #### Análise: alunos por mês (2023 - 2024)

# %%
df_receitas.groupby(["Descrição"]).count()['mensalidade']
# Out:
# Descrição
# #CLIENTE#23001    15
# #CLIENTE#23002    16
# #CLIENTE#23003    16
# #CLIENTE#23004    12
# #CLIENTE#23005     9
#                   ..
# #CLIENTE#24025     1
# #CLIENTE#24026     1
# #CLIENTE#24027     2
# #CLIENTE#24028     2
# #CLIENTE#24029     1
# Name: mensalidade, Length: 143, dtype: int64

# %%
df_receitas.dtypes
# Out:
# Data           datetime64[ns]
# Descrição              object
# Valor                 float64
# Tipo                   object
# mensalidade           float64
# receita               float64
# dtype: object

# %%
df_receitas['Data'] = df_receitas['Data'].dt.strftime('%Y-%m')

# %% [markdown]
# Agrupar clientes por ano e mês:

# %%
df_receitas.groupby("Data").count()['mensalidade']
# Out:
# Data
# 2023-01    36
# 2023-02    76
# 2023-03    77
# 2023-04    84
# 2023-05    79
# 2023-06    79
# 2023-07    76
# 2023-08    87
# 2023-09    94
# 2023-10    91
# 2023-11    87
# 2023-12    82
# 2024-01    86
# 2024-02    87
# 2024-03    88
# 2024-04    89
# Name: mensalidade, dtype: int64

# %%
query = df_receitas.groupby("Data").count().reset_index()

# %% [markdown]
# Vamos visualizar esses dados graficamente:

# %%
plt.rcParams['figure.figsize'] = [10, 5]
plt.bar(x = query['Data'], height = query['mensalidade'])
plt.xticks(rotation=45, ha='right');

# %% [markdown]
# #### Análise: Faturamento por mês

# %%
query = df_receitas.groupby("Data").agg({'Valor': 'sum'})

plt.rcParams['figure.figsize'] = [10, 5]
plt.plot(query.index, query['Valor'])
plt.xticks(rotation=45, ha='right');

# %% [markdown]
# #### Base CRM -  Análise Funil

# %%
df_CRM = pd.read_excel("/content/drive/MyDrive/CRM - CBS Dance Factory 2023 e 2024.xlsx")

# %%
df_CRM.head()
# Out:
#   CRM - Gerenciamento de Relacionamento com o Cliente           Unnamed: 1  \
# 0                                               QTDE       DATA 1º CONTATO
# 1                                                  1   2022-01-07 00:00:00
# 2                                                  2   2022-01-07 00:00:00
# 3                                                  3   2021-01-05 00:00:00
# 4                                                  4   2021-01-05 00:00:00
#
#                            Unnamed: 2 Unnamed: 3     Unnamed: 4  \
# 0                       NOME COMPLETO      IDADE       TELEFONE
# 1                            Graziele         22  12 99614-0592
# 2                            Camila       ADULTO  11 94129-6714
# 3                       MAIARA GOUVEA         16     98841-5432
# 4  ENIALE RAMOS QUINTINO (MÃE ELAINE)         11     99124-9509
#
#           Unnamed: 5 Unnamed: 6 Unnamed: 7        Unnamed: 8 Unnamed: 9  \
# 0             STATUS        VIA    ESTILOS  DATA AGENDAMENTO    HORÁRIO
# 1  AULA EXPERIMENTAL   WHATSAPP  JAZZ FUNK               NaN      18h30
# 2        INFORMAÇÕES   WHATSAPP       JAZZ               NaN      19H30
# 3  AULA EXPERIMENTAL      WHATS      K-POP               NaN      19H00
# 4  AULA EXPERIMENTAL      WHATS       JAZZ               NaN      17H00
#
#   Unnamed: 10  Unnamed: 11    Unnamed: 12       Unnamed: 13  Unnamed: 14  \
# 0   PROFESSOR   COMPARECEU  REAGENDAMENTO          SITUAÇÃO  OBSERVAÇÕES
# 1     ALISSON          SIM            NaN       MATRICULADO          NaN
# 2         LIA          NÃO            NaN  SEMANA SOLIDÁRIA          NaN
# 3     ALISSON    NÃO FICOU            NaN      NÃO RESPONDE          NaN
# 4         LIA  MATRICULADO            NaN       MATRICULADO          NaN
#
#   Unnamed: 15
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %% [markdown]
# #### Transformações da base CRM

# %% [markdown]
# Correção da header

# %%
header = df_CRM.iloc[0]
df_CRM = df_CRM[1:]
df_CRM.columns = header

# %%
df_CRM.head()
# Out:
# 0 QTDE      DATA 1º CONTATO                       NOME COMPLETO   IDADE  \
# 1    1  2022-01-07 00:00:00                            Graziele      22
# 2    2  2022-01-07 00:00:00                            Camila    ADULTO
# 3    3  2021-01-05 00:00:00                       MAIARA GOUVEA      16
# 4    4  2021-01-05 00:00:00  ENIALE RAMOS QUINTINO (MÃE ELAINE)      11
# 5    5  2022-01-07 00:00:00                                 Bia  ADULTO
#
# 0       TELEFONE             STATUS       VIA      ESTILOS DATA AGENDAMENTO  \
# 1  12 99614-0592  AULA EXPERIMENTAL  WHATSAPP    JAZZ FUNK              NaN
# 2  11 94129-6714        INFORMAÇÕES  WHATSAPP         JAZZ              NaN
# 3     98841-5432  AULA EXPERIMENTAL     WHATS        K-POP              NaN
# 4     99124-9509  AULA EXPERIMENTAL     WHATS         JAZZ              NaN
# 5  12 98129-7939        INFORMAÇÕES  WHATSAPP  MODALIDADES              NaN
#
# 0 HORÁRIO PROFESSOR   COMPARECEU REAGENDAMENTO          SITUAÇÃO OBSERVAÇÕES  \
# 1   18h30   ALISSON          SIM           NaN       MATRICULADO         NaN
# 2   19H30       LIA          NÃO           NaN  SEMANA SOLIDÁRIA         NaN
# 3   19H00   ALISSON    NÃO FICOU           NaN      NÃO RESPONDE         NaN
# 4   17H00       LIA  MATRICULADO           NaN       MATRICULADO         NaN
# 5       -         -          NÃO           NaN  SEMANA SOLIDÁRIA         NaN
#
# 0  NaN
# 1  NaN
# 2  NaN
# 3  NaN
# 4  NaN
# 5  NaN

# %% [markdown]
# Vamos eliminar algumas colunas irrelevantes para essa análise

# %%
df_CRM.drop(columns = ['OBSERVAÇÕES',
                       'REAGENDAMENTO',
                       'PROFESSOR',
                       'HORÁRIO',
                       'DATA AGENDAMENTO',
                       'TELEFONE',
                       'NOME COMPLETO',
                       'QTDE'
                       ], inplace = True)

# %%
# Eliminar a coluna "NaN"
df_CRM = df_CRM.iloc[:, 0:7]

# %%
df_CRM.head()
# Out:
# 0      DATA 1º CONTATO   IDADE             STATUS       VIA      ESTILOS  \
# 1  2022-01-07 00:00:00      22  AULA EXPERIMENTAL  WHATSAPP    JAZZ FUNK
# 2  2022-01-07 00:00:00  ADULTO        INFORMAÇÕES  WHATSAPP         JAZZ
# 3  2021-01-05 00:00:00      16  AULA EXPERIMENTAL     WHATS        K-POP
# 4  2021-01-05 00:00:00      11  AULA EXPERIMENTAL     WHATS         JAZZ
# 5  2022-01-07 00:00:00  ADULTO        INFORMAÇÕES  WHATSAPP  MODALIDADES
#
# 0   COMPARECEU          SITUAÇÃO
# 1          SIM       MATRICULADO
# 2          NÃO  SEMANA SOLIDÁRIA
# 3    NÃO FICOU      NÃO RESPONDE
# 4  MATRICULADO       MATRICULADO
# 5          NÃO  SEMANA SOLIDÁRIA

# %%
df_CRM.shape
# Out:
# (1679, 7)

# %% [markdown]
# 1679 linhas

# %%
df_CRM.nunique()
# Out:
# 0
# DATA 1º CONTATO    535
# IDADE               93
# STATUS              10
# VIA                 13
# ESTILOS             49
# COMPARECEU          56
# SITUAÇÃO           232
# dtype: int64

# %%
df_CRM.groupby('STATUS').count()
# Out:
# 0                  DATA 1º CONTATO  IDADE  VIA  ESTILOS  COMPARECEU  SITUAÇÃO
# STATUS
# AULA AVULSA                      3      3    3        3           3         3
# AULA ESPERIMENTAL                1      1    1        1           1         1
# AULA EXPERIMENTAL              891    869  891      891         880       878
# CAPTAÇÃO                        62     59   62       62          62        62
# COREOGRAFIA                      1      1    1        1           1         1
# INFORMACOES                      1      1    1        1           1         1
# INFORMAÇOES                      1      1    1        1           1         1
# INFORMAÇÃO                       1      1    1        1           1         1
# INFORMAÇÕES                    709    494  709      705         705       702
# INFORMAÇÕES                      3      3    3        3           3         3

# %% [markdown]
# Como podemos ver, há várias linhas que representam a mesma coisa (informação). Vamos padronizar isso para "INFORMAÇÕES" e "AULA EXPERIMENTAL"

# %%
for i in ['INFORMACOES', 'INFORMAÇOES', 'INFORMAÇÃO']:
  df_CRM['STATUS'] = df_CRM['STATUS'].str.replace(i, 'INFORMAÇÕES')

# %%
df_CRM['STATUS'] = df_CRM['STATUS'].str.replace('INFORMAÇÕES ', 'INFORMAÇÕES')

# %%
df_CRM['STATUS'] = df_CRM['STATUS'].str.replace('AULA ESPERIMENTAL', 'AULA EXPERIMENTAL')

# %%
df_CRM.groupby('STATUS').count()
# Out:
# 0                  DATA 1º CONTATO  IDADE  VIA  ESTILOS  COMPARECEU  SITUAÇÃO
# STATUS
# AULA AVULSA                      3      3    3        3           3         3
# AULA EXPERIMENTAL              892    870  892      892         881       879
# CAPTAÇÃO                        62     59   62       62          62        62
# COREOGRAFIA                      1      1    1        1           1         1
# INFORMAÇÕES                    715    500  715      711         711       708

# %%
df_CRM.groupby('SITUAÇÃO').count()
# Out:
# 0                                         DATA 1º CONTATO  IDADE  STATUS  VIA  \
# SITUAÇÃO
# -                                                      13     13      13   13
# 2 ANOS DE IDADE, MUITO PEQUENA PRA AULA.                1      1       1    1
# 2º SEMESTRE                                             3      3       3    3
# ADOROU, VAI FECHAR EM AGOSTO!                           1      1       1    1
# AGENDADO                                               28     28      28   28
# ...                                                   ...    ...     ...  ...
# VEIO 19/07 - vai pensar e retorna                       1      1       1    1
# VEIO 23/06 - NÃO VAI FICAR                              2      1       2    2
# VEIO 27/08                                              1      1       1    1
# VEIO ACOMPANHAR AMIGO                                   1      1       1    1
# VOLTA EM 2024                                           2      2       2    2
#
# 0                                         ESTILOS  COMPARECEU
# SITUAÇÃO
# -                                              13          13
# 2 ANOS DE IDADE, MUITO PEQUENA PRA AULA.        1           1
# 2º SEMESTRE                                     3           3
# ADOROU, VAI FECHAR EM AGOSTO!                   1           1
# AGENDADO                                       28          24
# ...                                           ...         ...
# VEIO 19/07 - vai pensar e retorna               1           1
# VEIO 23/06 - NÃO VAI FICAR                      2           2
# VEIO 27/08                                      1           1
# VEIO ACOMPANHAR AMIGO                           1           1
# VOLTA EM 2024                                   2           2
#
# [232 rows x 6 columns]

# %% [markdown]
# Como a granularidade está muito pequena para a coluna 'SITUAÇÃO' (há 232 valores distintos), vou utilizar a coluna 'STATUS' para fazer a análise de funil.

# %%
funil = df_CRM.groupby('STATUS').count()['VIA'].sort_values(ascending=False).head(10)

# %%
funil
# Out:
# STATUS
# AULA EXPERIMENTAL    892
# INFORMAÇÕES          715
# CAPTAÇÃO              62
# AULA AVULSA            3
# COREOGRAFIA            1
# Name: VIA, dtype: int64

# %%
topo_funil = funil['AULA EXPERIMENTAL']
meio_funil = funil['INFORMAÇÕES']
fundo_funil = funil['CAPTAÇÃO']

# %%
df_funil = pd.DataFrame({'Labels': ['AULA EXPERIMENTAL','INFORMAÇÕES','CAPTAÇÃO'],\
                         'Values': [topo_funil, meio_funil, fundo_funil]\
                         })

# %%
df_funil.head()
# Out:
#               Labels  Values
# 0  AULA EXPERIMENTAL     892
# 1        INFORMAÇÕES     715
# 2           CAPTAÇÃO      62

# %% [markdown]
# Plot funil

# %%
colors = ["#a9d18e", "#ed7d31", "#4472c4"]

fig = plt.figure(figsize=(12,10))

plt.fill_betweenx(y=[1, 3.8], x1=[10,12], x2=[8,6], color=colors[0]);
plt.fill_betweenx(y=[4, 6.8], x1=[12,14], x2=[6,4], color=colors[1]);
plt.fill_betweenx(y=[7, 9.8], x1=[14,16], x2=[4,2], color=colors[2]);

plt.xticks([],[]);
plt.yticks([2,5,8], df_funil["Labels"][::-1]);

for y, value in zip([2,5,8], df_funil["Values"][::-1]):
    plt.text(9, y, value, fontsize=16, fontweight="bold", color="white", ha="center");

plt.ylabel("Estágios");
plt.title("Funil de vendas", loc="center", fontsize=25, fontweight="bold");

# %% [markdown]
# #Conclusão

# %% [markdown]
# A análise permitiu identificar padrões relevantes no comportamento financeiro e operacional da empresa, além de inconsistências cadastrais presentes na base de CRM.
#
# Durante o projeto foram aplicados processos de limpeza, transformação e padronização de dados para melhorar a qualidade das informações analisadas. Também foram desenvolvidas análises temporais de faturamento, acompanhamento da evolução de alunos e visualização do funil de captação.
#
# Os resultados obtidos demonstram como a análise de dados pode auxiliar na identificação de gargalos operacionais, acompanhamento de indicadores e apoio à tomada de decisão.
#
# Como próximos passos, o projeto pode evoluir para dashboards interativos, automação de pipelines de dados e modelos preditivos para análise de retenção e comportamento de clientes.
